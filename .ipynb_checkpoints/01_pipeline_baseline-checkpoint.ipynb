# %%
#1.Imports
# numpy: operaciones numéricas eficientes (arrays, logaritmos, medias, etc.)
import numpy as np

# pandas: manipulación de datos tabulares (DataFrames)
import pandas as pd

# GEOparse: descarga y lectura de datasets del repositorio GEO
# nos permite acceder directamente a datasets de expresión génica
import GEOparse

# matplotlib: generación de gráficos
import matplotlib.pyplot as plt

# Pipeline: permite encadenar pasos (preprocesado + modelo)
# clave para evitar data leakage dentro de validación cruzada
from sklearn.pipeline import Pipeline

# StandardScaler: normaliza variables (media=0, var=1)
# necesario para modelos sensibles a escala (SVM, regresión)
from sklearn.preprocessing import StandardScaler

# VarianceThreshold: elimina variables con poca variabilidad
# útil para quitar genes irrelevantes
# SelectKBest: selecciona las K mejores variables según un criterio
# f_classif: ANOVA, mide relación entre variable y clase
from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_classif

# StratifiedKFold: validación cruzada manteniendo proporción de clases
# cross_validate: ejecuta CV y devuelve métricas
from sklearn.model_selection import StratifiedKFold, cross_validate

# Modelos de clasificación
from sklearn.linear_model import LogisticRegression  # modelo lineal interpretable
from sklearn.svm import SVC                           # SVM (potente en alta dimensión)
from sklearn.ensemble import RandomForestClassifier   # modelo robusto basado en árboles

import time
import winsound  # solo Windows

# %%
#2. CONFIGURACIÓN

# Fijamos semilla para reproducibilidad
# esto asegura que los resultados sean replicables
RANDOM_STATE = 42

# Número de variables (genes) que se seleccionarán
# hiperparámetro importante que controla complejidad del modelo
K_VALUES = [20, 50, 100, 500, 1000]

# %%
#3. Dataset
# Descargamos el dataset GSE2034 desde GEO
# si ya está descargado, se reutiliza (no descarga otra vez)
gse = GEOparse.get_GEO("GSE2034", destdir="../data")
# Out:
# 25-Mar-2026 15:26:38 DEBUG utils - Directory ../data already exists. Skipping.
# 25-Mar-2026 15:26:38 INFO GEOparse - File already exist: using local version.
# 25-Mar-2026 15:26:38 INFO GEOparse - Parsing ../data\GSE2034_family.soft.gz:
# 25-Mar-2026 15:26:38 DEBUG GEOparse - DATABASE: GeoMiame
# 25-Mar-2026 15:26:38 DEBUG GEOparse - SERIES: GSE2034
# 25-Mar-2026 15:26:39 DEBUG GEOparse - PLATFORM: GPL96
# 25-Mar-2026 15:26:39 DEBUG GEOparse - SAMPLE: GSM36777
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36778
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36779
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36780
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36781
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36782
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36783
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36784
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36785
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36786
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36787
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36788
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36789
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36790
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36791
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36792
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36793
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36794
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36795
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36796
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36797
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36798
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36799
# 25-Mar-2026 15:26:40 DEBUG GEOparse - SAMPLE: GSM36800
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36801
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36802
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36803
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36804
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36805
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36806
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36807
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36808
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36809
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36810
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36811
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36812
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36813
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36814
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36815
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36816
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36817
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36818
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36819
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36820
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36821
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36822
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36823
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36824
# 25-Mar-2026 15:26:41 DEBUG GEOparse - SAMPLE: GSM36825
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36826
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36827
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36828
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36829
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36830
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36831
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36832
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36833
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36834
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36835
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36836
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36837
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36838
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36839
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36840
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36841
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36842
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36843
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36844
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36845
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36846
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36847
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36848
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36849
# 25-Mar-2026 15:26:42 DEBUG GEOparse - SAMPLE: GSM36850
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36851
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36852
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36853
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36854
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36855
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36856
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36857
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36858
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36859
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36860
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36861
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36862
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36863
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36864
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36865
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36866
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36867
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36868
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36869
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36870
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36871
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36872
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36873
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36874
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36875
# 25-Mar-2026 15:26:43 DEBUG GEOparse - SAMPLE: GSM36876
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36877
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36878
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36879
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36880
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36881
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36882
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36883
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36884
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36885
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36886
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36887
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36888
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36889
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36890
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36891
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36892
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36893
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36894
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36895
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36896
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36897
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36898
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36899
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36900
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36901
# 25-Mar-2026 15:26:44 DEBUG GEOparse - SAMPLE: GSM36902
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36903
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36904
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36905
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36906
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36907
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36908
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36909
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36910
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36911
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36912
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36913
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36914
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36915
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36916
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36917
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36918
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36919
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36920
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36921
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36922
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36923
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36924
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36925
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36926
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36927
# 25-Mar-2026 15:26:45 DEBUG GEOparse - SAMPLE: GSM36928
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36929
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36930
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36931
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36932
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36933
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36934
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36935
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36936
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36937
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36938
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36939
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36940
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36941
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36942
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36943
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36944
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36945
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36946
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36947
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36948
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36949
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36950
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36951
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36952
# 25-Mar-2026 15:26:46 DEBUG GEOparse - SAMPLE: GSM36953
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36954
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36955
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36956
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36957
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36958
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36959
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36960
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36961
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36962
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36963
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36964
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36965
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36966
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36967
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36968
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36969
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36970
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36971
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36972
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36973
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36974
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36975
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36976
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36977
# 25-Mar-2026 15:26:47 DEBUG GEOparse - SAMPLE: GSM36978
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36979
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36980
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36981
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36982
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36983
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36984
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36985
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36986
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36987
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36988
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36989
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36990
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36991
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36992
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36993
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36994
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36995
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36996
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36997
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36998
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM36999
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM37000
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM37001
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM37002
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM37003
# 25-Mar-2026 15:26:48 DEBUG GEOparse - SAMPLE: GSM37004
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37005
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37006
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37007
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37008
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37009
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37010
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37011
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37012
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37013
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37014
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37015
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37016
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37017
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37018
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37019
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37020
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37021
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37022
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37023
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37024
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37025
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37026
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37027
# 25-Mar-2026 15:26:49 DEBUG GEOparse - SAMPLE: GSM37028
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37029
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37030
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37031
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37032
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37033
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37034
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37035
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37036
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37037
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37038
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37039
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37040
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37041
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37042
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37043
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37044
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37045
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37046
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37047
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37048
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37049
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37050
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37051
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37052
# 25-Mar-2026 15:26:50 DEBUG GEOparse - SAMPLE: GSM37053
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37054
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37055
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37056
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37057
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37058
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37059
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37060
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37061
# 25-Mar-2026 15:26:51 DEBUG GEOparse - SAMPLE: GSM37062

# %%
#4. Matriz de Expresión (X)
# Creamos un diccionario donde:
# clave = muestra (paciente)
# valor = vector de expresión génica
expr_data = {}

# Iteramos sobre todas las muestras del dataset
for gsm_name, gsm in gse.gsms.items():
    
    # gsm.table contiene los datos del microarray
    # ID_REF = identificador del gen/probe
    # VALUE = nivel de expresión
    
    # Convertimos la tabla en un vector indexado por genes
    expr_data[gsm_name] = gsm.table.set_index("ID_REF")["VALUE"]

# Convertimos el diccionario en DataFrame
# filas = muestras, columnas = genes
X = pd.DataFrame(expr_data).T

print("Shape X:", X.shape)
# Out:
# Shape X: (286, 22283)

# %%
#5. EXTRACCIÓN DE LABELS
# Lista donde guardaremos la variable objetivo (metástasis sí/no)
y = []

# Iteramos sobre cada muestra
for gsm_name, gsm in gse.gsms.items():
    
    # Obtenemos metadatos clínicos
    chars = gsm.metadata.get("characteristics_ch1", [])
    
    label = None
    
    # Buscamos el campo relevante
    for c in chars:
        c = c.lower()
        
        # Este dataset codifica la variable así:
        # "bone relapses (1=yes, 0=no): X"
        if "bone relapses" in c:
            
            # Extraemos el valor numérico (0 o 1)
            label = int(c.split(":")[-1].strip())
    
    # Si no encontramos etiqueta → error
    if label is None:
        raise ValueError(f"No se pudo extraer label para {gsm_name}")
    
    y.append(label)

# Convertimos a array numpy
y = np.array(y)

# Comprobamos distribución de clases
# importante para detectar errores en etiquetas
print("Distribución de clases:", np.bincount(y))

# Verificación de que hay exactamente dos clases
assert len(np.unique(y)) == 2, "Error: solo hay una clase"
# Out:
# Distribución de clases: [217  69]

# %%
#6. Transformación Logaritmica
# Aplicamos log2(x + 1)
# motivo:
# - los datos de microarray son altamente asimétricos
# - el log estabiliza la varianza y mejora modelos
X_log = np.log2(X + 1)

# %%
#7. Pipelines
# Definimos varios pipelines para comparar modelos
# cada pipeline incluye:
# preprocesado + selección + modelo

pipelines = {

    # Modelo baseline SIN selección de características
    # sirve como referencia para evaluar si la selección mejora resultados
    "LR baseline": Pipeline([
        ("variance", VarianceThreshold(threshold=0.01)),  # elimina genes poco variables
        ("scaler", StandardScaler()),                     # normaliza datos
        ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
    ]),

    # Logistic Regression + selección ANOVA
    "LR + SelectKBest": Pipeline([
        ("variance", VarianceThreshold(threshold=0.01)),
        ("scaler", StandardScaler()),
        ("select", SelectKBest(score_func=f_classif, k=K)),  # selecciona K mejores genes
        ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
    ]),

    # SVM con kernel RBF + selección
    "SVM (RBF) + SelectKBest": Pipeline([
        ("variance", VarianceThreshold(threshold=0.01)),
        ("scaler", StandardScaler()),
        ("select", SelectKBest(score_func=f_classif, k=K)),
        ("model", SVC(kernel="rbf", probability=True, random_state=RANDOM_STATE))
    ]),

    # Random Forest + selección
    # no usamos scaler porque RF no depende de la escala
    "RF + SelectKBest": Pipeline([
        ("variance", VarianceThreshold(threshold=0.01)),
        ("select", SelectKBest(score_func=f_classif, k=K)),
        ("model", RandomForestClassifier(
            n_estimators=100,
            random_state=RANDOM_STATE
        ))
    ])
}

# %%
# 8. VALIDACIÓN CRUZADA (EXPERIMENTO CON DISTINTOS K)
import time
from sklearn.feature_selection import mutual_info_classif, RFE

# Guardamos tiempo total del experimento
total_start = time.time()

# Validación cruzada estratificada (mantiene proporción de clases)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

# Lista donde guardaremos TODOS los resultados
all_results = []

# Loop sobre distintos valores de K (número de genes seleccionados)
for K in K_VALUES:

    print(f"\nEvaluando K = {K}")

    # Definimos pipelines dentro del loop (IMPORTANTE: K cambia)
    pipelines = {

        # --------------------------------------------------
        # BASELINE (sin selección de variables)
        # --------------------------------------------------
        "LR baseline": Pipeline([
            ("variance", VarianceThreshold(threshold=0.01)),  # elimina genes poco variables
            ("scaler", StandardScaler()),                     # normaliza datos
            ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
        ]),

        # --------------------------------------------------
        # ANOVA (selección univariante)
        # --------------------------------------------------
        "LR + ANOVA": Pipeline([
            ("variance", VarianceThreshold(threshold=0.01)),
            ("scaler", StandardScaler()),
            ("select", SelectKBest(score_func=f_classif, k=K)),  # selecciona K mejores genes
            ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
        ]),

        # --------------------------------------------------
        # MUTUAL INFORMATION (no lineal)
        # --------------------------------------------------
        "LR + MutualInfo": Pipeline([
            ("variance", VarianceThreshold(threshold=0.01)),
            ("scaler", StandardScaler()),
            ("select", SelectKBest(
                # usamos lambda para fijar random_state (detalle fino)
                score_func=lambda X, y: mutual_info_classif(X, y, random_state=RANDOM_STATE),
                k=K
            )),
            ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
        ]),

        # --------------------------------------------------
        # L1 (LASSO → selección implícita)
        # --------------------------------------------------
        #"LR L1": Pipeline([
        #    ("variance", VarianceThreshold(threshold=0.01)),
        #    ("scaler", StandardScaler()),
        #    ("model", LogisticRegression(
        #        penalty="l1",         # fuerza sparsity (coeficientes a 0)
        #        solver="saga",        # necesario para L1
        #        max_iter=5000,        # más iteraciones para converger
        #        C=0.1,                # regularización fuerte
        #        random_state=RANDOM_STATE
        #    ))
        #]),

        # --------------------------------------------------
        # RFE (selección multivariante iterativa)
        # --------------------------------------------------
        "LR + RFE": Pipeline([
            ("variance", VarianceThreshold(threshold=0.01)),
            ("scaler", StandardScaler()),
            ("select", RFE(
                estimator=LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
                n_features_to_select=K,
                step=50  # elimina 50 genes por iteración → acelera
            )),
            ("model", LogisticRegression(max_iter=1000, random_state=RANDOM_STATE))
        ])
    }

    # Loop sobre modelos
    for name, pipe in pipelines.items():

        # ⚠️ Evitamos ejecutar RFE para K grandes (demasiado lento)
        if name == "LR + RFE" and K > 5000:
            continue

        print(f"K={K} | Modelo: {name}")

        # Medimos tiempo por modelo
        start = time.time()

        # Validación cruzada (pipeline completo dentro de cada fold → sin leakage)
        scores = cross_validate(
            pipe,
            X_log,
            y,
            cv=cv,
            scoring={
                "roc_auc": "roc_auc",
                "f1": "f1",
                "accuracy": "accuracy"
            },
            return_train_score=False
        )

        end = time.time()
        print(f"Tiempo: {end - start:.2f} s")

        # ⚠️ L1 no depende de K → lo marcamos como "auto"
        if name == "LR L1":
            k_value = "auto"
        else:
            k_value = K

        # Guardamos resultados medios
        all_results.append({
            "Model": name,
            "K": k_value,
            "ROC-AUC": np.mean(scores["test_roc_auc"]),
            "F1": np.mean(scores["test_f1"]),
            "Accuracy": np.mean(scores["test_accuracy"])
        })


# ============================================================
# FIN DEL EXPERIMENTO
# ============================================================

# Tiempo total
total_end = time.time()
print(f"\nTiempo total: {total_end - total_start:.2f} s")

# Sonido al terminar (Windows)
import winsound
winsound.Beep(1000, 500)

print("\n=== FIN DEL EXPERIMENTO ===")
# Out:
# Evaluando K = 20
# K=20 | Modelo: LR baseline
# Tiempo: 3.68 s
# K=20 | Modelo: LR + ANOVA
# Tiempo: 2.59 s
# K=20 | Modelo: LR + MutualInfo
# Tiempo: 150.38 s
# K=20 | Modelo: LR + RFE
# Tiempo: 232.07 s
#
# Evaluando K = 50
# K=50 | Modelo: LR baseline
# Tiempo: 3.43 s
# K=50 | Modelo: LR + ANOVA
# Tiempo: 2.78 s
# K=50 | Modelo: LR + MutualInfo
# Tiempo: 152.82 s
# K=50 | Modelo: LR + RFE
# Tiempo: 226.56 s
#
# Evaluando K = 100
# K=100 | Modelo: LR baseline
# Tiempo: 4.17 s
# K=100 | Modelo: LR + ANOVA
# Tiempo: 2.91 s
# K=100 | Modelo: LR + MutualInfo
# Tiempo: 146.83 s
#
# Tiempo total: 928.22 s
#
# === FIN DEL EXPERIMENTO ===

# %%
#9. Resultados
# Convertimos a DataFrame
results_df = pd.DataFrame(all_results)

# Ordenamos por ROC-AUC
results_df = results_df.sort_values("ROC-AUC", ascending=False)

print(results_df)
# Out:
#               Model    K   ROC-AUC        F1  Accuracy
# 0       LR baseline   20  0.749616  0.485987  0.811252
# 8       LR baseline  100  0.749616  0.485987  0.811252
# 4       LR baseline   50  0.749616  0.485987  0.811252
# 10  LR + MutualInfo  100  0.640749  0.350020  0.709498
# 6   LR + MutualInfo   50  0.622552  0.300471  0.688808
# 1        LR + ANOVA   20  0.622219  0.251604  0.716999
# 2   LR + MutualInfo   20  0.595362  0.214364  0.695886
# 7          LR + RFE   50  0.585027  0.255770  0.699274
# 5        LR + ANOVA   50  0.582256  0.310716  0.699577
# 3          LR + RFE   20  0.547440  0.310616  0.678100
# 9        LR + ANOVA  100  0.544978  0.300774  0.688869

# %%
#10. Guardado
# Guardamos resultados en CSV
# importante para reproducibilidad y análisis posterior
import os

os.makedirs("../results", exist_ok=True)
results_df.to_csv("../results/results_baseline.csv")

# %%
#11. Visualizado
# seaborn mejora estética de gráficos
import seaborn as sns

# Estilo más limpio (tipo paper)
sns.set(style="whitegrid")


# ------------------------------------------------------------
# 1. Impacto de K en el rendimiento (GRÁFICO PRINCIPAL)
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))

sns.lineplot(
    data=results_df,
    x="K",
    y="ROC-AUC",
    hue="Model",
    marker="o"
)

plt.title("Impacto del número de genes (K) en el rendimiento (ROC-AUC)")
plt.xlabel("Número de genes seleccionados (K)")
plt.ylabel("ROC-AUC")

plt.tight_layout()
plt.show()


# ------------------------------------------------------------
# 2. Comparación de modelos para K alto (ej: K = 1000)
# ------------------------------------------------------------
# Elegimos el K más alto (puedes cambiarlo si quieres)
K_SELECTED = 1000

df_k = results_df[results_df["K"] == K_SELECTED]

plt.figure(figsize=(10, 6))

df_k.set_index("Model")[["ROC-AUC", "F1", "Accuracy"]].plot(kind="bar")

plt.title(f"Comparación de modelos (K = {K_SELECTED})")
plt.ylabel("Score")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()


# ------------------------------------------------------------
# 3. (Opcional) Evolución de F1-score
# ------------------------------------------------------------
plt.figure(figsize=(10, 6))

sns.lineplot(
    data=results_df,
    x="K",
    y="F1",
    hue="Model",
    marker="o"
)

plt.title("Impacto de K en F1-score")
plt.xlabel("Número de genes seleccionados (K)")
plt.ylabel("F1-score")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/lib.pyx:2407, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "auto"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 14
#       9 # ------------------------------------------------------------
#      10 # 1. Impacto de K en el rendimiento (GRÁFICO PRINCIPAL)
#      11 # ------------------------------------------------------------
#      12 plt.figure(figsize=(10, 6))
# ---> 14 sns.lineplot(
#      15     data=results_df,
#      16     x="K",
#      17     y="ROC-AUC",
#      18     hue="Model",
#      19     marker="o"
#      20 )
#      22 plt.title("Impacto del número de genes (K) en el rendimiento (ROC-AUC)")
#      23 plt.xlabel("Número de genes seleccionados (K)")
#
# File ~\.conda\envs\tfm_bio\lib\site-packages\seaborn\relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# File ~\.conda\envs\tfm_bio\lib\site-packages\seaborn\relational.py:276, in _LinePlotter.plot(self, ax, kws)
#     268 # TODO How to handle NA? We don't want NA to propagate through to the
#     269 # estimate/CI when some values are present, but we would also like
#     270 # matplotlib to show "gaps" in the line when all values are missing.
#    (...)
#     273
#     274 # Loop over the semantic subsets and add to the plot
#     275 grouping_vars = "hue", "size", "style"
# --> 276 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     278     if self.sort:
#     279         sort_vars = ["units", orient, other]
#
# File ~\.conda\envs\tfm_bio\lib\site-packages\seaborn\_base.py:902, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data, by_facet, allow_empty, dropna)
#     899 grouping_vars = [var for var in grouping_vars if var in self.variables]
#     901 if from_comp_data:
# --> 902     data = self.comp_data
#     903 else:
#     904     data = self.plot_data
#
# File ~\.conda\envs\tfm_bio\lib\site-packages\seaborn\_base.py:1000, in VectorPlotter.comp_data(self)
#     995 if var in self.var_levels:
#     996     # TODO this should happen in some centralized location
#     997     # it is similar to GH2419, but more complicated because
#     998     # supporting `order` in categorical plots is tricky
#     999     orig = orig[orig.isin(self.var_levels[var])]
# -> 1000 comp = pd.to_numeric(converter.convert_units(orig)).astype(float)
#    1001 transform = converter.get_transform().transform
#    1002 parts.append(pd.Series(transform(comp), orig.index, name=orig.name))
#
# File ~\.conda\envs\tfm_bio\lib\site-packages\pandas\core\tools\numeric.py:235, in to_numeric(arg, errors, downcast, dtype_backend)
#     233 coerce_numeric = errors not in ("ignore", "raise")
#     234 try:
# --> 235     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     236         values,
#     237         set(),
#     238         coerce_numeric=coerce_numeric,
#     239         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     240         or isinstance(values_dtype, StringDtype)
#     241         and values_dtype.na_value is libmissing.NA,
#     242     )
#     243 except (ValueError, TypeError):
#     244     if errors == "raise":
#
# File pandas/_libs/lib.pyx:2449, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "auto" at position 3

# %%
# FIN DEL EXPERIMENTO
# Tiempo total
total_end = time.time()
print(f"\nTiempo total: {total_end - total_start:.2f} s")

# Sonido al terminar (Windows)
import winsound
winsound.Beep(1000, 500)

print("\n=== FIN DEL EXPERIMENTO ===")
